# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.read_excel("taxis_data.xlsx")

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
df.describe()
# Out:
#                               pickup                        dropoff  \
# count                           6433                           6433
# mean   2019-03-16 08:31:28.514223616  2019-03-16 08:45:49.491217408
# min              2019-02-28 23:29:03            2019-02-28 23:32:35
# 25%              2019-03-08 15:50:34            2019-03-08 16:12:51
# 50%              2019-03-15 21:46:58            2019-03-15 22:06:44
# 75%              2019-03-23 17:41:38            2019-03-23 17:51:56
# max              2019-03-31 23:43:45            2019-04-01 00:13:58
# std                              NaN                            NaN
#
#         passengers     distance         fare         tip        tolls  \
# count  6433.000000  6433.000000  6433.000000  6433.00000  6433.000000
# mean      1.539251     3.024617    13.091073     1.97922     0.325273
# min       0.000000     0.000000     1.000000     0.00000     0.000000
# 25%       1.000000     0.980000     6.500000     0.00000     0.000000
# ...

# %%
df.groupby("payment").count()
# Out:
#              pickup  dropoff  passengers  distance  fare   tip  tolls  total  \
# payment
# cash           1789     1789        1789      1789  1789  1789   1789   1789
# credit card    4554     4554        4554      4554  4554  4554   4554   4554
#
#              color  pickup_zone  dropoff_zone  pickup_borough  \
# payment
# cash          1789         1786          1777            1786
# credit card   4554         4543          4536            4543
#
#              dropoff_borough  ride_duration  fare_per_mile  revenue  tip_pct
# payment
# cash                    1777           1789           1789     1789     1789
# credit card             4536           4554           4554     4554     4554

# %%
df.groupby("payment").count()
# Out:
#              pickup  dropoff  passengers  distance  fare   tip  tolls  total  \
# payment
# cash           1789     1789        1789      1789  1789  1789   1789   1789
# credit card    4554     4554        4554      4554  4554  4554   4554   4554
#
#              color  pickup_zone  dropoff_zone  pickup_borough  \
# payment
# cash          1789         1786          1777            1786
# credit card   4554         4543          4536            4543
#
#              dropoff_borough  ride_duration  fare_per_mile  revenue  tip_pct
# payment
# cash                    1777           1789           1789     1789     1789
# credit card             4536           4554           4554     4554     4554

# %% [markdown]
# ### Ride Distribution by Payment Type

# %%
payment_distribution = df['payment'].value_counts()
payment_distribution
# Out:
# payment
# credit card    4554
# cash           1789
# Name: count, dtype: int64

# %%
df.groupby("passengers")["fare"].mean()
# Out:
# passengers
# 0    12.734375
# 1    13.037061
# 2    13.167237
# 3    14.016461
# 4    13.040909
# 5    12.568592
# 6    14.042484
# Name: fare, dtype: float64

# %%
df.groupby("passengers").count()
# Out:
#             pickup  dropoff  distance  fare   tip  tolls  total  color  \
# passengers
# 0               96       96        96    96    96     96     96     96
# 1             4678     4678      4678  4678  4678   4678   4678   4678
# 2              876      876       876   876   876    876    876    876
# 3              243      243       243   243   243    243    243    243
# 4              110      110       110   110   110    110    110    110
# 5              277      277       277   277   277    277    277    277
# 6              153      153       153   153   153    153    153    153
#
#             payment  pickup_zone  dropoff_zone  pickup_borough  \
# passengers
# 0                90           96            96              96
# 1              4646         4656          4643            4656
# 2               871          873           870             873
# 3               243          242           240             242
# ...

# %%
df.groupby("color")["fare"].mean()
# Out:
# color
# green     14.040886
# yellow    12.919963
# Name: fare, dtype: float64

# %%
df["fare"].max()
# Out:
# 150.0

# %%
df.nlargest(10,"fare")
# Out:
#                   pickup             dropoff  passengers  distance   fare  \
# 5364 2019-03-17 16:59:17 2019-03-17 18:04:08           2     36.70  150.0
# 5648 2019-03-19 14:21:35 2019-03-19 15:51:28           2     33.46  150.0
# 4050 2019-03-13 14:05:19 2019-03-13 15:01:16           6     33.76  143.5
# 2231 2019-03-11 10:17:31 2019-03-11 11:03:55           1     26.35  130.0
# 622  2019-03-12 19:52:36 2019-03-12 19:52:55           3      0.00  120.0
# 3644 2019-03-19 23:30:50 2019-03-19 23:32:33           2      0.00  103.0
# 4815 2019-03-08 11:25:08 2019-03-08 11:50:30           3     10.36  100.0
# 4219 2019-03-08 20:07:54 2019-03-08 21:10:00           1     36.66   96.5
# 5567 2019-03-07 00:28:57 2019-03-07 02:02:55           1     25.51   93.5
# 3500 2019-03-11 17:18:03 2019-03-11 18:27:48           1     24.63   87.5
#
#         tip  tolls   total   color      payment           pickup_zone  \
# 5364   0.00  24.02  174.82  yellow         cash           JFK Airport
# ...

# %%
df.nlargest(10,"fare")["fare"]
# Out:
# 5364    150.0
# 5648    150.0
# 4050    143.5
# 2231    130.0
# 622     120.0
# 3644    103.0
# 4815    100.0
# 4219     96.5
# 5567     93.5
# 3500     87.5
# Name: fare, dtype: float64

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
sns.histplot(df["fare"])
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
sns.histplot(df["fare"],bins=30)
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
sns.scatterplot(x="distance",y="fare",data=df)
# Out:
# <Axes: xlabel='distance', ylabel='fare'>

# %%
df = pd.read_excel("Taxis_Data.xlsx", sheet_name="Taxis")
df['pickup'] = pd.to_datetime(df['pickup'])
df['dropoff'] = pd.to_datetime(df['dropoff'])
df['ride_duration'] = (df['dropoff'] - df['pickup']).dt.total_seconds() / 60

# %%
# Remove invalid entries
df = df[df['distance'] > 0]
df.describe()
# Out:
#                               pickup                        dropoff  \
# count                           6382                           6382
# mean   2019-03-16 08:28:06.100595456  2019-03-16 08:42:32.721717248
# min              2019-02-28 23:29:03            2019-02-28 23:32:35
# 25%              2019-03-08 15:50:56            2019-03-08 16:13:48
# 50%       2019-03-15 21:43:15.500000     2019-03-15 22:02:12.500000
# 75%    2019-03-23 17:44:31.249999872            2019-03-23 17:56:26
# max              2019-03-31 23:43:45            2019-04-01 00:13:58
# std                              NaN                            NaN
#
#         passengers     distance         fare          tip        tolls  \
# count  6382.000000  6382.000000  6382.000000  6382.000000  6382.000000
# mean      1.541836     3.048787    13.032070     1.974771     0.322777
# min       0.000000     0.010000     1.000000     0.000000     0.000000
# ...

# %% [markdown]
# ### Average fare per mile

# %%
df['fare_per_mile'] = df['fare'] / df['distance']
avg_fare_per_mile = df['fare_per_mile'].mean()
avg_fare_per_mile
# Out:
# 6.165725822569891

# %% [markdown]
# ### Total revenue

# %%
df['revenue'] = df['fare'] + df['tip'] + df['tolls']
total_revenue = df['revenue'].sum()
total_revenue
# Out:
# 97833.62

# %% [markdown]
# ### Tip percentage

# %%
df['tip_pct'] = df['tip'] / df['fare'] * 100
avg_tip_pct = df['tip_pct'].mean()
avg_tip_pct
# Out:
# 17.023082619242036

# %% [markdown]
# ### Common Pickup/Dropoff Zones

# %%
top_pickups = df['pickup_zone'].value_counts().head(10)
top_pickups
# Out:
# pickup_zone
# Midtown Center                  229
# Upper East Side South           211
# Penn Station/Madison Sq West    210
# Clinton East                    207
# Midtown East                    198
# Upper East Side North           186
# Times Sq/Theatre District       183
# Union Sq                        180
# Lincoln Square East             176
# Murray Hill                     162
# Name: count, dtype: int64

# %%
top_dropoffs = df['dropoff_zone'].value_counts().head(10)
top_dropoffs
# Out:
# dropoff_zone
# Upper East Side North           245
# Murray Hill                     220
# Midtown Center                  214
# Upper East Side South           176
# Midtown East                    176
# Times Sq/Theatre District       159
# Lincoln Square East             155
# East Village                    150
# Clinton East                    150
# Penn Station/Madison Sq West    148
# Name: count, dtype: int64

# %% [markdown]
# ### Ride Trends Over Time

# %%
df['pickup_hour'] = df['pickup'].dt.hour
df['pickup_date'] = df['pickup'].dt.date

# %%
df['pickup_hour']
# Out:
# 0       20
# 1       16
# 2       17
# 3        1
# 4       13
#         ..
# 6428     9
# 6429    17
# 6430    22
# 6431    10
# 6432    19
# Name: pickup_hour, Length: 6382, dtype: int32

# %%
df['pickup_date']
# Out:
# 0       2019-03-23
# 1       2019-03-04
# 2       2019-03-27
# 3       2019-03-10
# 4       2019-03-30
#            ...
# 6428    2019-03-31
# 6429    2019-03-31
# 6430    2019-03-23
# 6431    2019-03-04
# 6432    2019-03-13
# Name: pickup_date, Length: 6382, dtype: object

# %%
df['pickup_hour'].value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='pickup_hour'>

# %%
df['pickup_date'].value_counts().sort_index().plot(kind='line')
# Out:
# <Axes: xlabel='pickup_date'>

# %%
df['weekday'] = df['pickup'].dt.day_name()
df.pivot_table(index='pickup_hour', columns='weekday', values='fare', aggfunc='count')
# Out:
# weekday      Friday  Monday  Saturday  Sunday  Thursday  Tuesday  Wednesday
# pickup_hour
# 0              40.0    13.0      53.0    48.0      22.0     13.0       14.0
# 1              15.0     2.0      36.0    28.0      15.0      8.0        6.0
# 2              21.0     6.0      31.0    25.0       7.0      1.0       10.0
# 3              12.0     1.0      17.0    27.0       8.0      1.0        1.0
# 4              10.0     3.0      16.0    18.0       4.0      5.0        NaN
# 5              14.0     5.0       6.0     7.0       7.0      8.0        4.0
# 6              29.0    27.0       7.0    12.0      18.0     26.0       18.0
# 7              39.0    29.0      11.0    20.0      41.0     36.0       43.0
# 8              67.0    45.0      32.0    23.0      53.0     35.0       58.0
# 9              45.0    36.0      41.0    36.0      46.0     53.0       61.0
# 10             55.0    39.0      50.0    44.0      40.0     36.0       60.0
# ...

# %%
df['pickup_hour'].value_counts().sort_index()
# Out:
# pickup_hour
# 0     203
# 1     110
# 2     101
# 3      67
# 4      56
# 5      51
# 6     137
# 7     219
# 8     313
# 9     318
# 10    324
# 11    294
# 12    330
# 13    313
# 14    352
# 15    327
# 16    334
# 17    384
# 18    416
# 19    405
# 20    364
# 21    354
# 22    317
# 23    293
# Name: count, dtype: int64
